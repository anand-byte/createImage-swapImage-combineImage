# %% [markdown]
# # Creating an image with the cv

# %%
import cv2 
import numpy as np

## Creating blank image with numpy array

image = np.zeros((800,1000,3))

## open cv data type
image = image.astype(np.uint8)

##first row
image[0:200,0:200] = [255,255,255]
image[200:400,200:400]= [255,255,255]
image[0:200,400:600]= [255,255,255]

## second row
image[200:400,600:800]= [255,255,255]
image[0:200,800:1000]= [255,255,255]

## Third row
image[400:600,0:200]= [255,255,255]
image[400:600,400:600]= [255,255,255]
image[400:600,800:1000]= [255,255,255]

#last row
image[600:,200:400]= [255,255,255]
image[600:,600:800]= [255,255,255]

## showing image
cv2.imshow("image",image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image)

# %%
# Saving image
cv2.imwrite("Created_img.png",image)
# Out:
# True

# %% [markdown]
# # swapping cropped part

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
## read images

im1 = cv2.imread("first_image.jpg")

im2 = cv2.imread("second_image.jpg")
im3=im1

# %%
# orignal image
plt.imshow(im1)

# %%
# orignal image
plt.imshow(im2)

# %%
#face dimensions
im1_1 = im3[0:100,10:80]
plt.imshow(im1_1)

# %%
im2_1 = im2[0:100,10:80]
plt.imshow(im1_2)

# %%
im1[0:100,10:80]=im2_1
plt.imshow(im1)

# %%
im2[0:100,10:80]=im1_1
plt.imshow(im2)

# %% [markdown]
# # Take 2 image and combine it to form single image

# %%
## read images

im1 = cv2.imread("first_image.jpg")

im2 = cv2.imread("second_image.jpg")
im3=im1

# %%
img1=cv2.resize(im1,(400,400))
img2=cv2.resize(im2,(400,400))

# %%
img=np.hstack([img1,img2])

# %%
plt.imshow(img)

# %%
cv2.imwrite("img_combined.jpg",img)
# Out:
# True
